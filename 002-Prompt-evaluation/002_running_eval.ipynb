# %% [markdown]
# # Running the eval

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_messages(messages, text, role="user"):
    message = {"role": role, "content": text}
    messages.append(message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_messages(messages, prompt, role="user")
    add_messages(messages, "```json", role="assistant")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

# Save dataset to file
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=4)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_messages(messages, prompt, role="user")
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=4))
# Out:
# [
#     {
#         "output": "# AWS S3 Bucket Name Validator\n\n```python\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> tuple[bool, str]:\n    \"\"\"\n    Validates an AWS S3 bucket name according to AWS naming rules.\n    \n    Rules:\n    - Must be between 3 and 63 characters long\n    - Can only contain lowercase letters, numbers, and hyphens\n    - Must start with a lowercase letter or number\n    - Must end with a lowercase letter or number\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name: The S3 bucket name to validate\n        \n    Returns:\n        A tuple of (is_valid: bool, message: str)\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False, \"Bucket name must be a string\"\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3:\n        return False, \"Bucket name must be at least 3 characters long\"\n    \n    if len(bucket_name) > 63:\n        return False, \"Bucket name must not exceed 63 characters\"\n    \n    # Check if it contains only lowercase letters, numbers, and hyphens\n    if not re.match(r\"^[a-z0-9-]+$\", bucket_name):\n        return False, \"Bucket name can only contain lowercase letters, numbers, and hyphens\"\n    \n    # Check if it starts with a lowercase letter or number\n    if not re.match(r\"^[a-z0-9]\", bucket_name):\n        return False, \"Bucket name must start with a lowercase letter or number\"\n    \n    # Check if it ends with a lowercase letter or number\n    if not re.match(r\"[a-z0-9]$\", bucket_name):\n        return False, \"Bucket name must end with a lowercase letter or number\"\n    \n    # Check if it's formatted as an IP address\n    if re.match(r\"^(\\d{1,3}\\.){3}\\d{1,3}$\", bucket_name):\n        return False, \"Bucket name cannot be formatted as an IP address\"\n    \n    return True, \"Bucket name is valid\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid names\n        (\"my-bucket\", True),\n        (\"bucket123\", True),\n        (\"a1b2c3\", True),\n        (\"test-bucket-name\", True),\n        (\"abc\", True),  # minimum length\n        (\"a\" * 63, True),  # maximum length\n        \n        # Invalid names\n        (\"\", False),  # too short\n        (\"ab\", False),  # too short\n        (\"a\" * 64, False),  # too long\n        (\"My-Bucket\", False),  # uppercase letters\n        (\"my_bucket\", False),  # underscores not allowed\n        (\"my bucket\", False),  # spaces not allowed\n        (\"-my-bucket\", False),  # starts with hyphen\n        (\"my-bucket-\", False),  # ends with hyphen\n        (\"192.168.1.1\", False),  # IP address format\n        (\"my..bucket\", False),  # consecutive dots\n        (None, False),  # not a string\n        (123, False),  # not a string\n        (\"my-bucket!\", False),  # special character\n    ]\n    \n    print(\"S3 Bucket Name Validation Tests\\n\" + \"=\" * 50)\n    \n    for bucket_name, expected_valid in test_cases:\n        is_valid, message = validate_s3_bucket_name(bucket_name)\n        status = \"\u2713 PASS\" if is_valid == expected_valid else \"\u2717 FAIL\"\n        print(f\"{status} | '{bucket_name}' -> {is_valid}\")\n        if is_valid != expected_valid:\n            print(f\"       Expected: {expected_valid}, Got: {is_valid} - {message}\")\n    \n    print(\"\\n\" +",
#         "test_case": {
#             "task": "Write a Python function that validates an AWS S3 bucket name according to AWS naming rules (3-63 characters, lowercase letters, numbers, and hyphens only, must start and end with a letter or number)."
#         },
#         "score": 10
#     },
#     {
#         "output": "# AWS IAM Read-Only S3 Bucket Policy\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation of Policy Components:\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Policy language version (2012-10-17 is current standard) |\n| **Statement** | Array of individual permissions |\n| **Sid** | Statement ID for clarity (optional but recommended) |\n| **Effect** | \"Allow\" grants the permission |\n| **Action** | Specific S3 operations allowed |\n| **Resource** | AWS ARN specifying the bucket and objects |\n\n## Permissions Granted:\n\n- **s3:GetObject** - Read objects from the bucket\n- **s3:GetObjectVersion** - Read specific object versions\n- **s3:ListBucket** - List bucket contents\n- **s3:GetBucketVersioning** - Check versioning status\n\nThis policy grants **read-only access** with no write, delete, or administrative permissions.",
#         "test_case": {
#             "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'."
#         },
#         "score": 10
#     },
#     {
#         "output": "# AWS S3 ARN Regular Expression\n\nHere's a comprehensive regular expression that matches valid AWS S3 bucket ARNs:\n\n```regex\n^arn:aws:s3:::[a-z0-9][a-z0-9\\-]{1,61}[a-z0-9]$\n```\n\n## Explanation\n\nLet me break down each component:\n\n| Part | Description |\n|------|-------------|\n| `^` | Start of string |\n| `arn:aws:s3:::` | Literal prefix for S3 bucket ARNs |\n| `[a-z0-9]` | First character (must be alphanumeric) |\n| `[a-z0-9\\-]{1,61}` | 1-61 middle characters (alphanumeric or hyphens) |\n| `[a-z0-9]` | Last character (must be alphanumeric) |\n| `$` | End of string |\n\n## Key Rules Enforced\n\n\u2705 **S3 bucket naming rules:**\n- Total length: 3-63 characters\n- Only lowercase letters, numbers, and hyphens\n- Cannot start or end with a hyphen\n- Cannot contain consecutive hyphens (optional - see variant below)\n\n## Usage Examples\n\n### Python\n```python\nimport re\n\npattern = r'^arn:aws:s3:::[a-z0-9][a-z0-9\\-]{1,61}[a-z0-9]$'\n\n# Valid examples\nprint(re.match(pattern, 'arn:aws:s3:::my-bucket'))  # \u2713 Match\nprint(re.match(pattern, 'arn:aws:s3:::bucket123'))  # \u2713 Match\nprint(re.match(pattern, 'arn:aws:s3:::a-b-c'))      # \u2713 Match\n\n# Invalid examples\nprint(re.match(pattern, 'arn:aws:s3:::my_bucket'))  # \u2717 No match (underscore)\nprint(re.match(pattern, 'arn:aws:s3:::-bucket'))    # \u2717 No match (starts with hyphen)\nprint(re.match(pattern, 'arn:aws:s3:::bucket-'))    # \u2717 No match (ends with hyphen)\n```\n\n### JavaScript\n```javascript\nconst pattern = /^arn:aws:s3:::[a-z0-9][a-z0-9\\-]{1,61}[a-z0-9]$/;\n\nconsole.log(pattern.test('arn:aws:s3:::my-bucket'));  // true\nconsole.log(pattern.test('arn:aws:s3:::bucket-'));    // false\n```\n\n## Enhanced Variant (with consecutive hyphen check)\n\nIf you also want to prevent consecutive hyphens (`--`):\n\n```regex\n^arn:aws:s3:::[a-z0-9](?!.*--)(?:[a-z0-9\\-]){1,61}[a-z0-9]$\n```\n\nThis uses a negative lookahead `(?!.*--)` to ensure no consecutive hyphens exist.",
#         "test_case": {
#             "task": "Write a regular expression that matches valid AWS ARN (Amazon Resource Name) format for S3 buckets (e.g., arn:aws:s3:::bucket-name)."
#         },
#         "score": 10
#     }
# ]
