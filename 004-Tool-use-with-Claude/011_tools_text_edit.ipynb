# %% [markdown]
# # The text edit tool
#
# > Important Note: Tool version strings can for all model versions can be found here: https://docs.anthropic.com/en/docs/agents-and-tools/tool-use/text-editor-tool
#
# Claude comes with one built-in tool that you don't need to create from scratch: the text editor tool. This tool gives Claude the ability to work with files and directories just like you would in a standard text editor.

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message

def add_messages(messages, message, role="user"):
    user_message = {
        "role": role,
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message

def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_messages(messages, response, role="assistant")
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_messages(messages, tool_results, role="user")

    return messages

# %%
messages = []
# add_messages(messages, "Open the main.py file and summarize its contents. And show the file path.", role="user")
add_messages(
    messages, 
    """ 
    Open the main.py file and write out a function to calculate pi to the 5th decimal place.

    Then create a test.py to test your implementation of the pi function.
    """, 
    role="user")
run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th decimal place and then create a test file for it.
#
# Let me start by looking at the main.py file:
# Now let me view the main.py file:
# Let me check the current directory structure:
# Let me try viewing the current directory by checking a relative path:
# Great! Now I can see the main.py file. Let me add a function to calculate pi to the 5th decimal place:
# Now let me create a test.py file to test the pi function:
# Perfect! Let me show you the main.py file to confirm the changes:
# Excellent! Now let me show you the test.py file:
# Perfect! I've successfully completed both tasks:
#
# ## Summary
#
# ### 1. **main.py** - Added `calculate_pi()` function
# The function uses the **Machin formula** to calculate pi to the 5th decimal place:
# - **Formula**: π/4 = 4*arctan(1/5) - arctan(1/239)
# - Implements arctan using a Taylor series
# - Uses Python's `Decimal` module for high precision
# - Returns pi rounded to exactly 5 decimal places: **3.14159**
#
# ### 2. **test.py** - Comprehensive test suite
# The test file includes:
# - **test_calculate_pi()**: 4 comprehensive tests
#   - Test 1: Verifies the result matches `math.pi` to 5 decimal places
#   - Test 2: Checks that result has at most 5 decimal places
#   - Test 3: Confirms the value is exactly 3.14159
#   - Test 4: Ensures the value is within reasonable bounds (3.14 < π < 3.15)
# - **test_greeting()**: Tests the existing greeting function
# - Formatted output with visual feedback (✓ checkmarks)
#
# You can run the tests with: `python test.py`
# [{'role': 'user',
#   'content': ' \n    Open the main.py file and write out a function to calculate pi to the 5th decimal place.\n\n    Then create a test.py to test your implementation of the pi function.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th decimal place and then create a test file for it.\n\nLet me start by looking at the main.py file:", type='text'),
#    ToolUseBlock(id='toolu_01Ss4gPwCHGX3h9xTS9ZsKXj', input={'command': 'view', 'path': ''}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Ss4gPwCHGX3h9xTS9ZsKXj',
#     'content': '"005_tools_multi-turn-conversations.ipynb\\n001_tools_function.ipynb\\n007_tools_using_multiple_tools.ipynb\\n004_tools_sending_tool_results.ipynb\\n009_tools_structured_data.ipynb\\n011_tools_text_edit.ipynb\\n006_tools_implementing_multiple_turns.ipynb\\n010_tools_fine_grained_tool_calling.ipynb\\n.backups\\n008_tools_batch_tools.ipynb\\n003_tools_handling_message_blocks.ipynb\\nmain.py\\n002_tools_schemas.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now let me view the main.py file:', type='text'),
#    ToolUseBlock(id='toolu_01GDYjQgTePuxr7ncx3eDHLk', input={'command': 'view', 'path': '/main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01GDYjQgTePuxr7ncx3eDHLk',
#     'content': "Error: Access denied: Path '/main.py' is outside the allowed directory",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me check the current directory structure:', type='text'),
#    ToolUseBlock(id='toolu_01JT3im1DBfxUB4Dhyf4CdFq', input={'command': 'view', 'path': '/'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JT3im1DBfxUB4Dhyf4CdFq',
#     'content': "Error: Access denied: Path '/' is outside the allowed directory",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me try viewing the current directory by checking a relative path:', type='text'),
#    ToolUseBlock(id='toolu_016pnDXwLP7jkgHNhRFKYjEs', input={'command': 'view', 'path': 'main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_016pnDXwLP7jkgHNhRFKYjEs',
#     'content': '"1: def greeting():\\n2:     return \\"Hello! How can I assist you today?\\""',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Great! Now I can see the main.py file. Let me add a function to calculate pi to the 5th decimal place:', type='text'),
#    ToolUseBlock(id='toolu_01SsC897bXwRL2hx9GTbkUBu', input={'command': 'str_replace', 'path': 'main.py', 'old_str': 'def greeting():\n    return "Hello! How can I assist you today?"', 'new_str': 'def greeting():\n    return "Hello! How can I assist you today?"\n\n\ndef calculate_pi():\n    """\n    Calculate pi to the 5th decimal place using the Machin formula.\n    \n    The Machin formula is: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    This converges quickly and gives us pi ≈ 3.14159\n    """\n    from decimal import Decimal, getcontext\n    \n    # Set precision high enough to get accurate 5 decimal places\n    getcontext().prec = 50\n    \n    # Use the Machin formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    # We\'ll compute arctan using the Taylor series\n    def arctan(x, num_terms=100):\n        """Calculate arctan(x) using Taylor series"""\n        x = Decimal(x)\n        result = Decimal(0)\n        for n in range(num_terms):\n            result += ((-1) ** n) * (x ** (2 * n + 1)) / (2 * n + 1)\n        return result\n    \n    pi = 4 * (4 * arctan(Decimal(1) / Decimal(5)) - arctan(Decimal(1) / Decimal(239)))\n    \n    # Round to 5 decimal places\n    pi_rounded = round(float(pi), 5)\n    \n    return pi_rounded'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01SsC897bXwRL2hx9GTbkUBu',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now let me create a test.py file to test the pi function:', type='text'),
#    ToolUseBlock(id='toolu_01V3UA87angBRxq8sM1WxBFt', input={'command': 'create', 'path': 'test.py', 'file_text': 'import math\nfrom main import calculate_pi, greeting\n\n\ndef test_calculate_pi():\n    """Test the calculate_pi function"""\n    \n    # Get the calculated pi value\n    calculated_pi = calculate_pi()\n    \n    # Get the expected pi value from math module\n    expected_pi = math.pi\n    \n    print("=" * 50)\n    print("Testing calculate_pi() function")\n    print("=" * 50)\n    print(f"Calculated Pi: {calculated_pi}")\n    print(f"Expected Pi:   {expected_pi}")\n    print(f"Match to 5 decimals: {round(expected_pi, 5)}")\n    print()\n    \n    # Test 1: Check if the result is close to math.pi\n    assert abs(calculated_pi - expected_pi) < 0.00001, \\\n        f"Pi value {calculated_pi} is not close enough to {expected_pi}"\n    print("✓ Test 1 passed: Calculated pi matches math.pi to 5 decimal places")\n    \n    # Test 2: Check if pi is rounded to exactly 5 decimal places\n    decimal_places = len(str(calculated_pi).split(\'.\')[-1]) if \'.\' in str(calculated_pi) else 0\n    assert decimal_places <= 5, \\\n        f"Pi should have at most 5 decimal places, got {decimal_places}"\n    print(f"✓ Test 2 passed: Pi has {decimal_places} decimal places (max 5)")\n    \n    # Test 3: Check if pi is approximately 3.14159\n    expected_rounded = 3.14159\n    assert calculated_pi == expected_rounded, \\\n        f"Pi should be 3.14159, got {calculated_pi}"\n    print(f"✓ Test 3 passed: Pi equals 3.14159")\n    \n    # Test 4: Check if pi is within reasonable bounds\n    assert 3.14 < calculated_pi < 3.15, \\\n        f"Pi should be between 3.14 and 3.15, got {calculated_pi}"\n    print(f"✓ Test 4 passed: Pi is within bounds (3.14 < pi < 3.15)")\n    \n    print()\n    print("=" * 50)\n    print("All tests passed! ✓")\n    print("=" * 50)\n\n\ndef test_greeting():\n    """Test the greeting function"""\n    print("\\nTesting greeting() function")\n    print("=" * 50)\n    result = greeting()\n    print(f"Greeting result: {result}")\n    assert isinstance(result, str), "Greeting should return a string"\n    assert "Hello" in result, "Greeting should contain \'Hello\'"\n    print("✓ Greeting function works correctly")\n    print("=" * 50)\n\n\nif __name__ == "__main__":\n    test_greeting()\n    test_calculate_pi()\n'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01V3UA87angBRxq8sM1WxBFt',
#     'content': '"Successfully created test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me show you the main.py file to confirm the changes:', type='text'),
#    ToolUseBlock(id='toolu_01S2LtEJuG2YBeC2de3te4tD', input={'command': 'view', 'path': 'main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01S2LtEJuG2YBeC2de3te4tD',
#     'content': '"1: def greeting():\\n2:     return \\"Hello! How can I assist you today?\\"\\n3: \\n4: \\n5: def calculate_pi():\\n6:     \\"\\"\\"\\n7:     Calculate pi to the 5th decimal place using the Machin formula.\\n8:     \\n9:     The Machin formula is: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n10:     This converges quickly and gives us pi \\u2248 3.14159\\n11:     \\"\\"\\"\\n12:     from decimal import Decimal, getcontext\\n13:     \\n14:     # Set precision high enough to get accurate 5 decimal places\\n15:     getcontext().prec = 50\\n16:     \\n17:     # Use the Machin formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n18:     # We\'ll compute arctan using the Taylor series\\n19:     def arctan(x, num_terms=100):\\n20:         \\"\\"\\"Calculate arctan(x) using Taylor series\\"\\"\\"\\n21:         x = Decimal(x)\\n22:         result = Decimal(0)\\n23:         for n in range(num_terms):\\n24:             result += ((-1) ** n) * (x ** (2 * n + 1)) / (2 * n + 1)\\n25:         return result\\n26:     \\n27:     pi = 4 * (4 * arctan(Decimal(1) / Decimal(5)) - arctan(Decimal(1) / Decimal(239)))\\n28:     \\n29:     # Round to 5 decimal places\\n30:     pi_rounded = round(float(pi), 5)\\n31:     \\n32:     return pi_rounded"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Excellent! Now let me show you the test.py file:', type='text'),
#    ToolUseBlock(id='toolu_01XUmEu5coYQHSTsgnXZZoyo', input={'command': 'view', 'path': 'test.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01XUmEu5coYQHSTsgnXZZoyo',
#     'content': '"1: import math\\n2: from main import calculate_pi, greeting\\n3: \\n4: \\n5: def test_calculate_pi():\\n6:     \\"\\"\\"Test the calculate_pi function\\"\\"\\"\\n7:     \\n8:     # Get the calculated pi value\\n9:     calculated_pi = calculate_pi()\\n10:     \\n11:     # Get the expected pi value from math module\\n12:     expected_pi = math.pi\\n13:     \\n14:     print(\\"=\\" * 50)\\n15:     print(\\"Testing calculate_pi() function\\")\\n16:     print(\\"=\\" * 50)\\n17:     print(f\\"Calculated Pi: {calculated_pi}\\")\\n18:     print(f\\"Expected Pi:   {expected_pi}\\")\\n19:     print(f\\"Match to 5 decimals: {round(expected_pi, 5)}\\")\\n20:     print()\\n21:     \\n22:     # Test 1: Check if the result is close to math.pi\\n23:     assert abs(calculated_pi - expected_pi) < 0.00001, \\\\\\n24:         f\\"Pi value {calculated_pi} is not close enough to {expected_pi}\\"\\n25:     print(\\"\\u2713 Test 1 passed: Calculated pi matches math.pi to 5 decimal places\\")\\n26:     \\n27:     # Test 2: Check if pi is rounded to exactly 5 decimal places\\n28:     decimal_places = len(str(calculated_pi).split(\'.\')[-1]) if \'.\' in str(calculated_pi) else 0\\n29:     assert decimal_places <= 5, \\\\\\n30:         f\\"Pi should have at most 5 decimal places, got {decimal_places}\\"\\n31:     print(f\\"\\u2713 Test 2 passed: Pi has {decimal_places} decimal places (max 5)\\")\\n32:     \\n33:     # Test 3: Check if pi is approximately 3.14159\\n34:     expected_rounded = 3.14159\\n35:     assert calculated_pi == expected_rounded, \\\\\\n36:         f\\"Pi should be 3.14159, got {calculated_pi}\\"\\n37:     print(f\\"\\u2713 Test 3 passed: Pi equals 3.14159\\")\\n38:     \\n39:     # Test 4: Check if pi is within reasonable bounds\\n40:     assert 3.14 < calculated_pi < 3.15, \\\\\\n41:         f\\"Pi should be between 3.14 and 3.15, got {calculated_pi}\\"\\n42:     print(f\\"\\u2713 Test 4 passed: Pi is within bounds (3.14 < pi < 3.15)\\")\\n43:     \\n44:     print()\\n45:     print(\\"=\\" * 50)\\n46:     print(\\"All tests passed! \\u2713\\")\\n47:     print(\\"=\\" * 50)\\n48: \\n49: \\n50: def test_greeting():\\n51:     \\"\\"\\"Test the greeting function\\"\\"\\"\\n52:     print(\\"\\\\nTesting greeting() function\\")\\n53:     print(\\"=\\" * 50)\\n54:     result = greeting()\\n55:     print(f\\"Greeting result: {result}\\")\\n56:     assert isinstance(result, str), \\"Greeting should return a string\\"\\n57:     assert \\"Hello\\" in result, \\"Greeting should contain \'Hello\'\\"\\n58:     print(\\"\\u2713 Greeting function works correctly\\")\\n59:     print(\\"=\\" * 50)\\n60: \\n61: \\n62: if __name__ == \\"__main__\\":\\n63:     test_greeting()\\n64:     test_calculate_pi()\\n65: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully completed both tasks:\n\n## Summary\n\n### 1. **main.py** - Added `calculate_pi()` function\nThe function uses the **Machin formula** to calculate pi to the 5th decimal place:\n- **Formula**: π/4 = 4*arctan(1/5) - arctan(1/239)\n- Implements arctan using a Taylor series\n- Uses Python's `Decimal` module for high precision\n- Returns pi rounded to exactly 5 decimal places: **3.14159**\n\n### 2. **test.py** - Comprehensive test suite\nThe test file includes:\n- **test_calculate_pi()**: 4 comprehensive tests\n  - Test 1: Verifies the result matches `math.pi` to 5 decimal places\n  - Test 2: Checks that result has at most 5 decimal places\n  - Test 3: Confirms the value is exactly 3.14159\n  - Test 4: Ensures the value is within reasonable bounds (3.14 < π < 3.15)\n- **test_greeting()**: Tests the existing greeting function\n- Formatted output with visual feedback (✓ checkmarks)\n\nYou can run the tests with: `python test.py`", type='text')]}]
