# %%
# Load environment variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()

model = "claude-sonnet-4-0"

# %%
def add_message(messages, content, role):
    message = {"role": role, "content": content}
    messages.append(message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    
    return message.content[0].text

# %%
# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add it to a list of messages
    add_message(messages, user_input, role="user")

    # Call the API
    answer = chat(messages)
    
    # Add generated text to the list messages
    add_message(messages, answer, role="assistant")

    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > what's 1+1
# ---
# 1 + 1 = 2
# > and add more 2
# ---
# 2 + 2 = 4
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 14
#      11 add_message(messages, user_input, role="user")
#      13 # Call the API
# ---> 14 answer = chat(messages)
#      16 # Add generated text to the list messages
#      17 add_message(messages, answer, role="assistant")
#
# Cell In[8], line 6, in chat(messages)
#       5 def chat(messages):
# ----> 6     message = client.messages.create(
#       7         model=model,
#       8         max_tokens=1000,
#       9         messages=messages,
#      10     )
#      12     return message.content[0].text
#
# File ~/Documents/workspace/playground/claude-code/building-with-the-Claude-API/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Documents/workspace/playground/claude-code/building-with-the-Claude-API/.venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:932, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     925 if model in DEPRECATED_MODELS:
#     926     warnings.warn(
#     927         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     928         DeprecationWarning,
#     929         stacklevel=3,
#     930     )
# --> 932 return self._post(
#     933     "/v1/messages",
#     934     body=maybe_transform(
#     935         {
#     936             "max_tokens": max_tokens,
#     937             "messages": messages,
#     938             "model": model,
#     939             "metadata": metadata,
#     940             "service_tier": service_tier,
#     941             "stop_sequences": stop_sequences,
#     942             "stream": stream,
#     943             "system": system,
#     944             "temperature": temperature,
#     945             "thinking": thinking,
#     946             "tool_choice": tool_choice,
#     947             "tools": tools,
#     948             "top_k": top_k,
#     949             "top_p": top_p,
#     950         },
#     951         message_create_params.MessageCreateParamsStreaming
#     952         if stream
#     953         else message_create_params.MessageCreateParamsNonStreaming,
#     954     ),
#     955     options=make_request_options(
#     956         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     957     ),
#     958     cast_to=Message,
#     959     stream=stream or False,
#     960     stream_cls=Stream[RawMessageStreamEvent],
#     961 )
#
# File ~/Documents/workspace/playground/claude-code/building-with-the-Claude-API/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1361, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1352     warnings.warn(
#    1353         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1354         "Please pass raw bytes via the `content` parameter instead.",
#    1355         DeprecationWarning,
#    1356         stacklevel=2,
#    1357     )
#    1358 opts = FinalRequestOptions.construct(
#    1359     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1360 )
# -> 1361 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/workspace/playground/claude-code/building-with-the-Claude-API/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1134, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1131             err.response.read()
#    1133         log.debug("Re-raising status error")
# -> 1134         raise self._make_status_error_from_response(err.response) from None
#    1136     break
#    1138 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.4: all messages must have non-empty content except for the optional final assistant message'}, 'request_id': 'req_011CXbHfmTrFXMeCKvzSEvnF'}
